# %% [markdown]
# # Linear Regression with Regularization using Sklearn
# ##  CPE 490 590
# ### Author: Rahul Bhadani

# %% [markdown]
# # Let's read the data first

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split, cross_val_score
from statistics import mean
plt.rcParams['font.family'] = 'Serif'
plt.rcParams['font.size'] = 15

data = pd.read_csv("Dataset/HousePrices/kc_house_data.csv")
data.dropna(inplace=True) #remove drop na
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
# Drop the non-sensical variables that are not useful for regression
dropColumns = ['id', 'date', 'zipcode']
data = data.drop(dropColumns, axis = 1)
data.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7      1180.0              0      1955             0
# 1     0          3      7      2170.0            400      1951          1991
# 2     0          3      6       770.0              0      1933             0
# 3     0          5      7      1050.0            910      1965             0
# 4     0          3      8      1680.0              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15
# 0  47.5112 -122.257           1340        5650
# 1  47.7210 -122.319           1690        7639
# 2  47.7379 -122.233           2720        8062
# 3  47.5208 -122.393           1360        5000
# 4  47.6168 -122.045           1800        7503

# %% [markdown]
# # Separating the dependent and independent variables

# %%
y = data['price']
X = data.drop('price', axis = 1)
 
# Dividing the data into training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %% [markdown]
# # Building and evaluating the different models
# ## Linear Regression (without Regularization)

# %%
linearModel = LinearRegression()
linearModel.fit(X_train, y_train)
 
# Evaluating the Linear Regression model on the test dataset
print(linearModel.score(X_test, y_test))
# Out:
# 0.6934864815021954

# %% [markdown]
# Check the accuracy you got from the Linear Regression without regularization

# %% [markdown]
# ## Ridge(L2) Regression:

# %% [markdown]
# Note: in `Ridge` python class, $\alpha$ is the regularization parameter (we had this as $\lambda$ in the lecture slide).

# %%
# List to maintain the different cross-validation scores
cross_val_scores_ridge = []
 
# List to maintain the different values of alpha
alpha = []

accuracy_list = []
 
# Loop to compute the different values of cross-validation scores
for i in range(1, 9):
    ridgeModel = Ridge(alpha = i * 0.25)
    ridgeModel.fit(X_train, y_train)
    scores = cross_val_score(ridgeModel, X, y, cv = 10)
    avg_cross_val_score = mean(scores)*100
    cross_val_scores_ridge.append(avg_cross_val_score)
    alpha.append(i * 0.25)
    
    accuracy_list.append(ridgeModel.score(X_test, y_test))
# Loop to print the different values of cross-validation scores
for i in range(0, len(alpha)):
    print('Lambda:' + str(alpha[i])+'. Cross validation score: '+str(cross_val_scores_ridge[i]) + '   accuracy: {}'.format(accuracy_list[i]))
# Out:
# Lambda:0.25. Cross validation score: 69.09015837671014   accuracy: 0.693520645552318
# Lambda:0.5. Cross validation score: 69.09033468066406   accuracy: 0.6935543845685911
# Lambda:0.75. Cross validation score: 69.09049125083845   accuracy: 0.6935877027561026
# Lambda:1.0. Cross validation score: 69.0906282899928   accuracy: 0.6936206042698895
# Lambda:1.25. Cross validation score: 69.09074599856251   accuracy: 0.6936530932156438
# Lambda:1.5. Cross validation score: 69.09084457469034   accuracy: 0.6936851736504144
# Lambda:1.75. Cross validation score: 69.09092421425656   accuracy: 0.6937168495832948
# Lambda:2.0. Cross validation score: 69.09098511090886   accuracy: 0.6937481249761016

# %% [markdown]
# Which value of Lambda gives the best accuracy?

# %% [markdown]
# ## Lasso (L1) Regression

# %%
# Building and fitting the Lasso Regression Model
lassoModelChosen = Lasso(alpha = 2, tol = 0.0925)
lassoModelChosen.fit(X_train, y_train)

# Evaluating the Lasso Regression model
print(lassoModelChosen.score(X_test, y_test))
# Out:
# 0.6934933963463207

# %% [markdown]
# Which Model Performed Best?
